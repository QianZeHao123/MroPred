# %%
import pandas as pd

model_eval_result = pd.read_csv('./Out/best_experiments_log.csv')
model_eval_result
# Out:
#            Timestamp  Best Epoch  \
# 0    20250509_141122          15
# 1    20250509_143611          10
# 2    20250509_152916          38
# 3    20250509_161530          23
# 4    20250509_165422          25
# ..               ...         ...
# 96   20250512_073428           8
# 97   20250512_081043           7
# 98   20250512_084450          21
# 99   20250512_093045           8
# 100  20250512_101842           8
#
#                                      Agg Function  Max Seq Length  \
# 0                                        ['mean']               4
# 1    ['mean', 'sum', 'max', 'min', 'std', 'skew']              20
# 2                                        ['mean']               4
# 3    ['mean', 'sum', 'max', 'min', 'std', 'skew']               8
# 4                                             sum              20
# ..                                            ...             ...
# 96   ['mean', 'sum', 'max', 'min', 'std', 'skew']              16
# ...

# %%
max_val_f1_rows = model_eval_result[
    model_eval_result["Val F1"] == model_eval_result["Val F1"].max()
]
first_max_row = model_eval_result.loc[[model_eval_result["Val F1"].idxmax()]]
max_val_f1_rows
# Out:
#           Timestamp  Best Epoch                                  Agg Function  \
# 68  20250511_084217          15  ['mean', 'sum', 'max', 'min', 'std', 'skew']
#
#     Max Seq Length  Learning Rate RNN Type  RNN Output Size  RNN Layers  \
# 68               8       0.000446     LSTM              128           2
#
#     Bidirectional Pooling Method  ...  Train Precision  Train AUC  Val Loss  \
# 68           True            NaN  ...         0.065196   0.625108  1.948671
#
#       Val F1  Val Accuracy  Val Recall  Val Precision   Val AUC  \
# 68  0.115602      0.565551     0.60208        0.06394  0.616517
#
#                                         Log File Path  \
# 68  ./Out/training_log_20250511_084217_test/traini...
#
#                                       Model Save Path
# 68  ./Out/training_log_20250511_084217_test/models...
#
# [1 rows x 26 columns]

# %%
lr = 0.0005
max_seq_length = 8
agg_fun = ["mean", "sum", "max", "min", "std", "skew"]
rnn_type = "LSTM"
rnn_output_size = 128
rnn_layers = 2
bidirectional = True
pooling_method = None
num_heads = None
Gamma = 7
