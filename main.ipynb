# %%
# import lightgbm as lgb
import pandas as pd
data = pd.read_csv('./Data/weekly_filter_new_2.csv', index_col=0)
data
# Out:
#                                                        id  yr_nbr  week_nbr  \
# 1        w4HClcKnwrzCv8KgwrjDi8Klwr3Cm8KVwqfCrsKowprClg==    2018         3
# 2        w4HClcKnwrzCv8KgwrjDi8Klwr3Cm8KVwqfCrsKowprClg==    2018         4
# 3        w4HClcKnwrzCv8KgwrjDi8Klwr3Cm8KVwqfCrsKowprClg==    2018         5
# 5        w4HClcKnwrzCv8KgwrjDi8Klwr3Cm8KVwqfCrsKowprClg==    2018         7
# 6        w4HClcKnwrzCv8KgwrjDi8Klwr3Cm8KVwqfCrsKowprClg==    2018         8
# ...                                                   ...     ...       ...
# 3972098  wrbCt8K1wrvDi8KtwrjCtMONwrvCrsKXwqbCqcKqwpzCnA==    2019        48
# 3972099  wrbCt8K1wrvDi8KtwrjCtMONwrvCrsKXwqbCqcKqwpzCnA==    2019        49
# 3972100  wrbCt8K1wrvDi8KtwrjCtMONwrvCrsKXwqbCqcKqwpzCnA==    2019        50
# 3972101  wrbCt8K1wrvDi8KtwrjCtMONwrvCrsKXwqbCqcKqwpzCnA==    2019        51
# 3972102  wrbCt8K1wrvDi8KtwrjCtMONwrvCrsKXwqbCqcKqwpzCnA==    2019        52
#
# ...
